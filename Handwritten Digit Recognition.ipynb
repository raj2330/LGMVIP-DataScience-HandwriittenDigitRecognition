# %%
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
for i in range(5):
    plt.matshow(X_train[i])

# %%
y_train[:5]
# Out:
# array([5, 0, 4, 1, 9], dtype=uint8)

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)

# %%
X_train_flattened.shape
# Out:
# (60000, 784)

# %%
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
X_test_flattened.shape
# Out:
# (10000, 784)

# %%
model = keras.Sequential([
    #Layer 1
    keras.layers.Dense(10, input_shape= (784,), activation="sigmoid")
    
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 9.5898 - accuracy: 0.8403
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 6.1360 - accuracy: 0.8798
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 5.7860 - accuracy: 0.8821
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 5.5811 - accuracy: 0.8860
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 5.4380 - accuracy: 0.8860

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
model = keras.Sequential([
    #Layer 1
    keras.layers.Dense(100, input_shape= (784,), activation="sigmoid"),
    keras.layers.Dense(10, activation="sigmoid")
    
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5558 - accuracy: 0.8489
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3692 - accuracy: 0.8934
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3265 - accuracy: 0.9025
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3197 - accuracy: 0.9031
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3017 - accuracy: 0.9091

# %%
model = keras.Sequential([
    #Layer 1
    keras.layers.Dense(500, input_shape= (784,), activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="relu")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 14.5095 - accuracy: 0.0990
# Epoch 2/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 14.5264 - accuracy: 0.0987
# Epoch 3/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 14.5264 - accuracy: 0.0987
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 14.5264 - accuracy: 0.0987
# Epoch 5/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 14.5264 - accuracy: 0.0987

# %%
model = keras.Sequential([
    #Layer 1
    keras.layers.Dense(512, input_shape= (784,), activation="sigmoid"),
    keras.layers.Dense(256, activation="sigmoid"),
    keras.layers.Dense(10, activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

model.fit(X_train_flattened, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.4012 - accuracy: 0.8846
# Epoch 2/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2882 - accuracy: 0.9114
# Epoch 3/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2505 - accuracy: 0.9236
# Epoch 4/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.2249 - accuracy: 0.9289
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2082 - accuracy: 0.9349
# Epoch 6/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1906 - accuracy: 0.9416
# Epoch 7/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1824 - accuracy: 0.9434
# Epoch 8/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1686 - accuracy: 0.9467
# Epoch 9/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1579 - accuracy: 0.9503
# Epoch 10/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1514 - accuracy: 0.9524

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1500 - accuracy: 0.9529
# [0.1499590128660202, 0.9528999924659729]

# %%
y_pred = model.predict(X_test_flattened)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
y_pred[0]
# Out:
# array([2.6124490e-03, 2.2484355e-02, 8.3865070e-01, 8.0036926e-01,
#        3.3062413e-05, 2.5180053e-02, 1.7369206e-07, 9.9996454e-01,
#        3.0230429e-02, 4.5181006e-01], dtype=float32)

# %%
np.argmax(y_pred[0])
# Out:
# 7

# %%
plt.matshow(X_test[0])

# %%
plt.matshow(X_test[0])

# %%
def find(index):
    result = np.argmax(y_pred[index])
    plt.matshow(X_test[index])
    plt.xlabel(result, size = 20)

# %%
for i in range(500,600):
    find(i)
# Out:
# C:\Users\dasra\AppData\Local\Temp\ipykernel_4812\1361225994.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.matshow(X_test[index])

# %%
y_predicted_labels = [np.argmax(i) for i in y_pred]
y_predicted_labels[:5]
# Out:
# [7, 2, 1, 0, 4]

# %%
y_test[:5]
# Out:
# array([7, 2, 1, 0, 4], dtype=uint8)

# %%
cm = tf.math.confusion_matrix(labels= y_test, predictions = y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 959,    1,    0,    0,    0,    5,   10,    1,    3,    1],
#        [   0, 1122,    2,    3,    0,    1,    2,    1,    4,    0],
#        [   8,    5,  974,   10,    2,    1,    5,    6,   21,    0],
#        [   0,    1,    3,  958,    0,    6,    0,    7,   33,    2],
#        [   0,    3,    6,    0,  922,    1,    8,    0,    7,   35],
#        [   3,    1,    2,   27,    4,  825,    7,    2,   18,    3],
#        [   9,    4,    3,    1,    5,    5,  923,    0,    8,    0],
#        [   0,    7,   14,    4,    2,    0,    0,  983,    1,   17],
#        [   2,    1,    2,   11,    5,    8,    5,    3,  931,    6],
#        [   6,    7,    0,   11,   18,    2,    1,   14,   18,  932]])>

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
# Out:
# <Axes: >
